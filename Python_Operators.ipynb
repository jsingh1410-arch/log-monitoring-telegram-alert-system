# %% [markdown]
# <a href="https://colab.research.google.com/github/jsingh1410-arch/log-monitoring-telegram-alert-system/blob/main/Python_Operators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Program demonstrating arithematic operators
a = 15
b = 4

# Arithematic operations
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b)
print("Modulus:", a % b)
print("Exponentiation:", a ** b)
print("Floor Divison:", a // b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Exponentiation: 50625
# Floor Divison: 3

# %%
# Program demonstrating assignment operators
num = 5
# Assignment operations
print("Initial value: num =", num)
num += 3 # Equivalent to num = num + 3
print("num += 3: num =", num)
num -= 2 # Equivalent to num = num - 2
print("num -= 2: num =", num)
num *= 4 # Equivalent to num = num * 4
print("num *= 4: num =", num)
# Out:
# Initial value: num = 5
# num += 3: num = 8
# num -= 2: num = 6
# num *= 4: num = 24
