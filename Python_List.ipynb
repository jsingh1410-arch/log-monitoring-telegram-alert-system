# %% [markdown]
# <a href="https://colab.research.google.com/github/jsingh1410-arch/log-monitoring-telegram-alert-system/blob/main/Python_List.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name1 = input("Enter your name: ")
print(name1)
age = int(input("Enter your age: ") )
gpa = float(input("enter your gpa: "))
print(gpa)
# Out:
# Enter your name: Kia
# Kia
# Enter your age: 15
# enter your gpa: 3.2
# 3.2
