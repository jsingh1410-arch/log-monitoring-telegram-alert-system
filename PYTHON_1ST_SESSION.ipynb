# %% [markdown]
# <a href="https://colab.research.google.com/github/jsingh1410-arch/log-monitoring-telegram-alert-system/blob/main/PYTHON_1ST_SESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We use the print command to display the messages.
print("Hello I am learning coding")
# Out:
# Hello I am learning coding

# %%
print(2+3)
# Out:
# 5

# %%
print("2+3")
2+3

# %%
my_weight = 70
my_city = "Texas"
print("My weight is- ", my_weight)
print("I live in",my_city)
# Out:
# My weight is-  70
# I live in Texas

# %%
print("Hello")
# Out:
# Hello

# %%
print("2")
# But we never write numbers in quotations.
print("2+2")
print(2+2)
print(10-2)
print(10*56)
print(72/8)
# Out:
# 2
# 2+2
# 4
# 8
# 560
# 9.0

# %%
print(2*"a")
print("hello"+"class")
# Out:
# aa
# helloclass

# %%
print(2+"a")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3422/151973098.py in <cell line: 0>()
# ----> 1 print(2+"a")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
